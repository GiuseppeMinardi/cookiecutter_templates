# %%
# %run ./setup.py

from pathlib import Path

import cool_styles

from matplotlib import pyplot as plt
from {{cookiecutter.repo_name}} import project_paths

plt.style.use(cool_styles.coastalarvest)
